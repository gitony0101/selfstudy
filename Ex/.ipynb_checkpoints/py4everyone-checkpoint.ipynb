# %%
print('hello')
# Out:
# hello

# %%
nzt = input('Enter your name:')
# Out:
# Enter your name: dd

# %%
print('hello', nzt)
# Out:
# hello dd

# %%
xh = input('Enter Hours:')
# Out:
# Enter Hours: 2

# %%
xr = input('Enter Rate:')
# Out:
# Enter Rate: 3

# %%
# xp =  xh * xr

# %%
# ooooops, classic errors, so let's improve the varaible type
xp = float(xh) * float(xr)

# %%
print("pay", xp)
# Out:
# pay 6.0

# %%
astr = 'Bob'
try:
    print('hello')
    istr = int(astr)
    print('There')
except:
    istr = -1
print('Done',istr)
# Out:
# hello
# Done -1
