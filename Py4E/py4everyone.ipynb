# %%
astr = 'Bob'
try:
    print('hello')
    istr = int(astr)
    print('There')
except:
    istr = -1
print('Done',istr)
# Out:
# hello
# Done -1

# %%
# chap6 strings

# %%
fruit = 'banana'
letter = fruit[1]
print(letter)
# Out:
# a

# %%
zot = 'abc'
print(zot[6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-ee7de94f7817> in <module>
#       1 zot = 'abc'
# ----> 2 print(zot[6])
#
# IndexError: string index out of range

# %%
print(len(fruit)) #banana
# Out:
# 6

# %%
fruit = 'banana'
index = 0
while index < len(fruit):
    letter = fruit[index]
    print(index, letter)
    index = index + 1 #interesting
# Out:
# 0 b
# 1 a
# 2 n
# 3 a
# 4 n
# 5 a

# %%
fruit = 'banana'
for letter in fruit:
    print(letter)
# Out:
# b
# a
# n
# a
# n
# a

# %%
word = 'banana'
count = 0
for letter in word:
    if letter == 'a':
        count = count + 1
print(count)
# Out:
# 3

# %%
for letter in 'banana':
    print(letter)
# Out:
# b
# a
# n
# a
# n
# a
